# %% [markdown]
# # Lets load the data file

# %%
import numpy as np
import pandas as pd 
import seaborn as sns

# %%
#This is the data file cell.


df=pd.read_csv("./TWO_CENTURIES_OF_UM_RACES.csv")
df.head(20)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_11732\308344789.py:4: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("./TWO_CENTURIES_OF_UM_RACES.csv")
#     Year of event Event dates           Event name Event distance/length  \
# 0            2018  06.01.2018  Selva Costera (CHI)                  50km
# 1            2018  06.01.2018  Selva Costera (CHI)                  50km
# 2            2018  06.01.2018  Selva Costera (CHI)                  50km
# 3            2018  06.01.2018  Selva Costera (CHI)                  50km
# 4            2018  06.01.2018  Selva Costera (CHI)                  50km
# 5            2018  06.01.2018  Selva Costera (CHI)                  50km
# 6            2018  06.01.2018  Selva Costera (CHI)                  50km
# 7            2018  06.01.2018  Selva Costera (CHI)                  50km
# 8            2018  06.01.2018  Selva Costera (CHI)                  50km
# ...

# %%
# OVERALL VIEW OF THE DATAFRAME 

df.count()




#OVERALL DESCRIPTION OF THE DATAFRAME 
#df.describe()
# Out:
# Year of event                7461195
# Event dates                  7461195
# Event name                   7461195
# Event distance/length        7460142
# Event number of finishers    7461195
# Athlete performance          7461193
# Athlete club                 4634671
# Athlete country              7461192
# Athlete year of birth        6873034
# Athlete gender               7461188
# Athlete age category         6876257
# Athlete average speed        7460971
# Athlete ID                   7461195
# dtype: int64

# %%
#SHAPE OF THE DATAFRAME 



df.shape
# Out:
# (7461195, 13)

# %%
# DATA TYPES OF THE DATAFRAME 
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
df.head()
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance        Athlete club  \
# 0                         22           4:51:39 h               Tnfrc
# 1                         22           5:15:45 h  Roberto Echeverría
# 2                         22           5:16:44 h   Puro Trail Osorno
# 3                         22           5:34:13 h            Columbia
# 4                         22           5:54:14 h      Baguales Trail
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# ...

# %%
#Cleaning the dataframe 


#I only want USA Races ,50mi ,2020

df[df["Event distance/length"]=="50km"]
#df[df["Athlete country"].str[0:2]=='USA']


#df[df["Athlete country"]=="USA"]


df.head()
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance        Athlete club  \
# 0                         22           4:51:39 h               Tnfrc
# 1                         22           5:15:45 h  Roberto Echeverría
# 2                         22           5:16:44 h   Puro Trail Osorno
# 3                         22           5:34:13 h            Columbia
# 4                         22           5:54:14 h      Baguales Trail
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# ...

# %%
df[df["Event distance/length"]=="50km"].head(25)


#Another way to do that 
df[df["Event distance/length"].isin(["50km","50mi"])]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
#This select both of them yk what 
#As we want also USA events and year of the event to be 2020  



df[df["Event distance/length"].isin(["50km","50mi"]) & (df["Year of event"]==2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...

# %%
#LETS SELCT ONLY USA EVENTS 




df[df["Event name"].str[-5:]=="(USA)"]
df[df["Event name"].str[-5:]=="(USA)"]
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
#ONLY THE PARTICULAR EVENT NAMED some particular event 
df[df["Event name"]=="Everglades 50 Mile Ultra Run (USA)"]["Event name"].str.split("(").str.get(1).str.split(")").str.get(0)
# Out:
# 51923      USA
# 51924      USA
# 51925      USA
# 51926      USA
# 51927      USA
#           ...
# 6417091    USA
# 6417092    USA
# 6417093    USA
# 6417094    USA
# 6417095    USA
# Name: Event name, Length: 338, dtype: object

# %%
df[df["Event name"].str.split("(").str.get(1).str.split(")").str.get(0)=="USA"]
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
#Easiest way for doing this 
df[df["Event name"].str[-5:]=="(USA)"]
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %% [markdown]
# # The new dataframe

# %%
df1=df[df["Event distance/length"].isin(["50km","50mi"]) & (df["Year of event"]==2020) & (df["Event name"].str[-5:]=="(USA)")]

# %%
df1.head()
df1.shape
# Out:
# (26524, 13)

# %%
df1=df[df["Event distance/length"].isin(["50km","50mi"]) & (df["Year of event"]==2020) & (df["Event name"].str[-5:]=="(USA)")]

# %%
df2 =df[df["Event distance/length"].isin(["50km","50mi"]) & (df["Year of event"]==2020) & (df["Event name"].str.split("(").str.get(1).str.split(")").str.get(0)=="USA")]
df2.shape
df2.head()
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance  \
# 2539945                         20           3:17:55 h
# 2539946                         20           4:02:32 h
# 2539947                         20           4:07:57 h
# 2539948                         20           4:22:02 h
# ...

# %%
# REMOVE USA FROM THE EVENT NAME
df2["Event name"]=df2["Event name"].str.split("(").str.get(0)


df2.head()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_11732\303264022.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Event name"]=df2["Event name"].str.split("(").str.get(0)
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
# Lets calculate athlate age 



df2["Athlete age"]=2020-df2["Athlete year of birth"]


df2.head()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_11732\1406912781.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Athlete age"]=2020-df2["Athlete year of birth"]
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %% [markdown]
# # Removing h from athlete performance

# %%
df2["Athlete performance"]=df2["Athlete performance"].str.split(" ").str.get(0)


df2.head()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_11732\3221567342.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Athlete performance"]=df2["Athlete performance"].str.split(" ").str.get(0)
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
# ...

# %%
#df2.drop(columns=["Athlete club","Athlete country","Athlete year of birth"])

#In general way to do this 

df2=df2.drop(["Athlete club","Athlete country","Athlete year of birth","Athlete age category"],axis=1)
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
# ...

# %%
#Cleaning up null values 





df2.isnull().sum()
print(df2.shape)

df2=df2.dropna()
print(df2.shape)
# Out:
# (26090, 10)
# (25857, 10)

# %% [markdown]
# # Check for duplicates

# %%
df2[df2.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, Athlete age]
# Index: []

# %%
#Reset index
df2.reset_index(drop=True)
# Out:
#        Year of event Event dates                                Event name  \
# 0               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 1               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 3               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 4               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...              ...         ...                                       ...
# 25852           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25853           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25854           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25855           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25856           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
#       Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
# Fix all the data types 
df2.dtypes


df2["Athlete age"]=df2["Athlete age"].astype(int)
df2.dtypes
# Out:
# Year of event                 int64
# Event dates                  object
# Event name                   object
# Event distance/length        object
# Event number of finishers     int64
# Athlete performance          object
# Athlete gender               object
# Athlete average speed        object
# Athlete ID                    int64
# Athlete age                   int64
# dtype: object

# %%
df2["Athlete average speed"]=df2["Athlete average speed"].astype(float)
df2.head()
#df2["Event distance/length"]=df2["Event distance/length"].astype(int)
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
# ...

# %%
#Rename columns




df3=df2.rename({
    "Year of event":"Year",
    "Event dates":"Race day",
    "Event name":"Race name",
    "Event distance/length":"Race_length",
    "Event number of finishers":"Race_number_of_finisher",
    "Athlete performance":"Athlete Performance",
    "Athlete gender":"Gender",
    "Athlete average speed":"Avg_Speed",
    "Athlete ID":"ID_no",
    "Athlete age":"Age"},axis=1)


df3.head()
# Out:
#          Year    Race day                                 Race name  \
# 2539945  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949  2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Race_length  Race_number_of_finisher Athlete Performance Gender  \
# 2539945        50km                       20             3:17:55      M
# 2539946        50km                       20             4:02:32      M
# 2539947        50km                       20             4:07:57      M
# 2539948        50km                       20             4:22:02      M
# 2539949        50km                       20             4:27:34      M
#
#          Avg_Speed   ID_no  Age
# 2539945     15.158   71287   29
# 2539946     12.369  629508   39
# ...

# %%
#Reorder the column 




df3[df3["Race name"]=="Everglades 50 Mile Ultra Run "]
# Out:
#          Year    Race day                      Race name Race_length  \
# 2591476  2020  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591477  2020  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591478  2020  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591479  2020  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591480  2020  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591481  2020  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591482  2020  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591483  2020  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591484  2020  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591485  2020  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591486  2020  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591487  2020  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2591488  2020  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# ...

# %%
df3[df3["ID_no"]==222509]
# Out:
#          Year    Race day                      Race name Race_length  \
# 2591482  2020  14.03.2020  Everglades 50 Mile Ultra Run         50mi
# 2616900  2020  22.02.2020       Manasota Track Club 50K         50km
#
#          Race_number_of_finisher Athlete Performance Gender  Avg_Speed  \
# 2591482                       40             9:19:10      M      8.634
# 2616900                       36             4:49:16      M     10.371
#
#           ID_no  Age
# 2591482  222509   23
# 2616900  222509   23

# %% [markdown]
# # Lets plot things out

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
import numpy as np  


sns.histplot(df3,x="Race_length",hue="Gender")
# Out:
# <Axes: xlabel='Race_length', ylabel='Count'>

# %%
sns.displot(df3[df3["Race length"]=="50mi"]["Avg_Speed"])

# %%
sns.violinplot(data=df3,x="Race length",y="Avg_Speed",hue="Gender")
# Out:
# <Axes: xlabel='Race length', ylabel='Avg_Speed'>

# %%
df3.head()

sns.lmplot(data=df3,x="Age",y="Avg_Speed",hue="Gender")

# %%
#Questions

# %% [markdown]
# # Questions
# 1.race_day
# 2.LENGTH
# 3.NAME
# AND REST OF ALL

# %%
df3.head(2)
# Out:
#          Year    Race day                                 Race name  \
# 2539945  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946  2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Race length  Race_number_of_finisher Athlete Performance Gender  \
# 2539945        50km                       20             3:17:55      M
# 2539946        50km                       20             4:02:32      M
#
#          Avg_Speed   ID_no  Age
# 2539945     15.158   71287   29
# 2539946     12.369  629508   39

# %%
#Difference in speed for 50km and 50mil male to female 


grouped_data=df3.groupby(["Race_length","Gender"])["Avg_Speed"].mean("")
grouped_data


#query() method allows you to filter or select rows in a DataFrame based on a condition that is expressed as a string
# Out:
# Race_length  Gender
# 50km         F         7.083011
#              M         7.738985
# 50mi         F         6.834371
#              M         7.257633
# Name: Avg_Speed, dtype: float64

# %%
#For calculating which age group people has best avarage speed and their number is at least 19

df3.query('Race_length=="50mi"').groupby("Age")["Avg_Speed"].agg(["mean","count"]).sort_values("mean",ascending=False).query("count>19")



#here count actually counts a particular age group peopleb the mean is displaced only if the particular age group people is greater than 19
# Out:
#          mean  count
# Age
# 29   7.902252    135
# 23   7.779800     55
# 28   7.575252    107
# 30   7.569204    157
# 25   7.540923     91
# 31   7.451638    138
# 38   7.430022    231
# 35   7.422359    195
# 36   7.403854    185
# 26   7.379800     75
# 33   7.379188    149
# 22   7.367902     41
# 24   7.354274     73
# 42   7.327656    209
# 34   7.319011    182
# 40   7.310669    236
# 21   7.304658     38
# 20   7.293778     27
# 32   7.287969    162
# 39   7.283648    227
# 37   7.220493    221
# 27   7.201748    119
# 41   7.197017    179
# 45   7.130667    156
# 47   7.085410    156
# 44   7.052642    179
# 51   7.019379    124
# 46   6.897236    174
# 43   6.884225    187
# 52   6.847400    130
# 55   6.828623     69
# 54   6.805506     83
# 49   6.789553    159
# 57   6.783205     78
# 53   6.736969     96
# 56   6.708373     67
# 48   6.696853    136
# 59   6.672072     83
# 50   6.671541    172
# 64   6.620727     22
# 58   6.582328     67
# 63   6.514806     31
# ...

# %%
#Lets Caclulate 
#For calculating which age group people has worst avarage speed and their number is at least 19

df3.query('Race_length=="50mi"').groupby("Age")["Avg_Speed"].agg(["mean","count"]).sort_values("mean",ascending=True).query('count>9')
# Out:
#          mean  count
# Age
# 70   5.470667     12
# 65   5.934786     14
# 68   5.957500     10
# 67   6.114909     11
# 66   6.194300     10
# 60   6.261788     33
# 62   6.272730     37
# 61   6.358355     31
# 63   6.514806     31
# 58   6.582328     67
# 64   6.620727     22
# 50   6.671541    172
# 59   6.672072     83
# 48   6.696853    136
# 56   6.708373     67
# 53   6.736969     96
# 57   6.783205     78
# 49   6.789553    159
# 54   6.805506     83
# 55   6.828623     69
# 52   6.847400    130
# 43   6.884225    187
# 46   6.897236    174
# 51   7.019379    124
# 44   7.052642    179
# 47   7.085410    156
# 45   7.130667    156
# 41   7.197017    179
# 27   7.201748    119
# 37   7.220493    221
# 39   7.283648    227
# 32   7.287969    162
# 20   7.293778     27
# 21   7.304658     38
# 40   7.310669    236
# 34   7.319011    182
# 42   7.327656    209
# 24   7.354274     73
# 22   7.367902     41
# 33   7.379188    149
# 26   7.379800     75
# 36   7.403854    185
# ...

# %%
df3.head()
df3["Race_month"]=df3["Race day"].str[3:5].astype(int)

def get_season(fahim):
    if fahim>11:
        return "Winter"
    elif fahim>8 and fahim<11:
        return "Fall"
    else:
        return "Summer"


df3["Race_month"]=df3["Race_month"].apply(lambda x:get_season(x))
df3.head(2)
# Out:
#          Year    Race day                                 Race name  \
# 2539945  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946  2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Race_length  Race_number_of_finisher Athlete Performance Gender  \
# 2539945        50km                       20             3:17:55      M
# 2539946        50km                       20             4:02:32      M
#
#          Avg_Speed   ID_no  Age Race month Race_month
# 2539945     15.158   71287   29     Summer     Summer
# 2539946     12.369  629508   39     Summer     Summer

# %%
df4=df3.groupby("Race_month")["Avg_Speed"].agg(["mean","count"])

dat=df3["Race_month"].unique()
df4["mean"]
dat2

plt.bar(dat,df4["mean"])
plt.xlabel("Season")
plt.ylabel("Mean Speed")
plt.show()

# %%
plt.bar(dat,df4["count"],color='orange')
plt.xlabel("Season")
plt.ylabel("Number of people Ran")
plt.show()
